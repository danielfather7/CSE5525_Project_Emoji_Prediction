# %%
import numpy as np
from scipy.sparse import csr_matrix
from sklearn.naive_bayes import MultinomialNB

from Emojidata import EMOJIdata

# %%
train = EMOJIdata("./data/us_train.text")
test = EMOJIdata("./data/us_test.text", vocab=train.vocab)

# %%
emojiMap = {}
for line in open("./data/us_mapping.txt"):
    line = line.split()    
    emojiMap[int(line[0])] = (line[1], line[2])
emojiMap
# Out:
# {0: ('❤', '_red_heart_'),
#  1: ('😍', '_smiling_face_with_hearteyes_'),
#  2: ('😂', '_face_with_tears_of_joy_'),
#  3: ('💕', '_two_hearts_'),
#  4: ('🔥', '_fire_'),
#  5: ('😊', '_smiling_face_with_smiling_eyes_'),
#  6: ('😎', '_smiling_face_with_sunglasses_'),
#  7: ('✨', '_sparkles_'),
#  8: ('💙', '_blue_heart_'),
#  9: ('😘', '_face_blowing_a_kiss_'),
#  10: ('📷', '_camera_'),
#  11: ('🇺🇸', '_United_States_'),
#  12: ('☀', '_sun_'),
#  13: ('💜', '_purple_heart_'),
#  14: ('😉', '_winking_face_'),
#  15: ('💯', '_hundred_points_'),
#  16: ('😁', '_beaming_face_with_smiling_eyes_'),
#  17: ('🎄', '_Christmas_tree_'),
#  18: ('📸', '_camera_with_flash_'),
#  19: ('😜', '_winking_face_with_tongue_')}

# %%
#baseline by most frequent tag
print("Most requent tag is: ", emojiMap[train.mostFreqLbl])
print("Baseline by most frequent tag: ", np.count_nonzero(test.Y == train.mostFreqLbl)/test.Y.shape[0])
# Out:
# Most requent tag is:  ('❤', '_red_heart_')
# Baseline by most frequent tag:  0.21596

# %%
# %%time
for alpha in [0.01, 0.05, 0.1, 0.5, 1.0, 5.0, 10.0]:
    clfs = []
    for gold in range(20):
        clf = MultinomialNB(alpha=alpha, fit_prior=True, class_prior=None)
        Y = np.copy(train.Y)
        Y[Y != gold] = -1
        clf.fit(train.X, Y)
        clfs.append(clf)
    probs = np.zeros((20,test.Y.shape[0]))
    for i in range(20):
        probs[i] = clfs[i].predict_proba(test.X)[:, 1]
    predTags = np.argmax(probs, axis=0)
    score = np.sum(np.equal(predTags, test.Y)) / test.Y.shape[0]
    print("Alpha = %.2f\tscore = %.5f" %(alpha, score))
# Out:
# Alpha = 0.01	score = 0.37264
# Alpha = 0.05	score = 0.38798
# Alpha = 0.10	score = 0.39256
# Alpha = 0.50	score = 0.36046
# Alpha = 1.00	score = 0.32578
# Alpha = 5.00	score = 0.25368
# Alpha = 10.00	score = 0.23856
# CPU times: user 1min 11s, sys: 2.75 s, total: 1min 14s
# Wall time: 18.8 s

# %%
# %%time
alpha = 0.1 #with best performance
clfs = []
for gold in range(20):
    clf = MultinomialNB(alpha=alpha, fit_prior=True, class_prior=None)
    Y = np.copy(train.Y)
    Y[Y != gold] = -1
    clf.fit(train.X, Y)
    clfs.append(clf)

probs = np.zeros((20,test.Y.shape[0]))
for i in range(20):
    probs[i] = clfs[i].predict_proba(test.X)[:, 1]

predTags = np.argmax(probs, axis=0)
score = np.sum(np.equal(predTags, test.Y)) / test.Y.shape[0]

score = np.sum(np.equal(predTags, test.Y)) / test.Y.shape[0]
print("Emoji Prediction by Naive Bayes with alpha=", alpha)
print("score: %.4f" % score)
print()
for i in range(20):
    print("For tag: ", emojiMap[i])
    coef = np.log(np.exp(clfs[i].feature_log_prob_[1]) 
                  / np.exp(clfs[i].feature_log_prob_[0]))
    coefSorted = np.argsort(coef)
    print("10 most important features: ")
    for coefid in coefSorted[-1:-11:-1]:
        print("{:<15}{:>.4f}".format(train.vocab.GetWord(coefid), coef[coefid]))
    print("10 least important features: ")
    for coefid in coefSorted[:10]:
        print("{:<15}{:>.4f}".format(train.vocab.GetWord(coefid), coef[coefid]))
    print()
# Out:
# Emoji Prediction by Naive Bayes with alpha= 0.1
# score: 0.3926
#
# For tag:  ('❤', '_red_heart_')
# 10 most important features:
# ️ny            9.0559
# ️nyc           8.3861
# ️u             7.6785
# ️️…            7.2890
# ️la            7.0608
# ️to            6.5982
# edmodo         6.2814
# ️ny…           6.2173
# #kfodiaries    6.2173
# ️miss          6.2173
# 10 least important features:
# :…             -5.8236
# #govote        -5.7479
# asf            -5.5696
# ).             -5.4859
# #godblessamerica-5.4080
# #electionday   -5.3944
# #teamusa       -5.3806
# #trump2016     -5.3806
# #vote2016      -5.2785
# sun!           -5.1297
#
# For tag:  ('😍', '_smiling_face_with_hearteyes_')
# 10 most important features:
# nlk            6.5157
# #goodfoodfridays6.3839
# tribez         6.3839
# #aboutlastfriday6.3839
# #böhemia…      6.3839
# #inkchurch     6.2321
# #laurasboutique6.2321
# allegiant      6.2321
# #theamericandreamteam6.2321
# #rawlsrealty   6.2321
# 10 least important features:
# ️              -8.3920
# ️…             -8.1934
# ️.             -6.9267
# niggas         -6.0978
# #election2016  -5.9053
# ️!             -5.8754
# mixtape        -5.7652
# ️ny            -5.7347
# #ivoted        -5.6992
# lit.           -5.2879
#
# For tag:  ('😂', '_face_with_tears_of_joy_')
# 10 most important features:
# lmaooo         7.9876
# #postavideoyoucantexplain7.9876
# lmao,          6.9466
# lmao!!         6.8672
# funniest_15seconds6.7809
# #souljaboy     6.5822
# hysterical     6.4658
# #crazyrealworld6.4658
# #funnyaf       6.4658
# foolin         6.4658
# 10 least important features:
# ️…             -8.2433
# ️️             -7.5610
# ️.             -6.9766
# ️              -6.3112
# ️ny            -5.7846
# #sunrise       -5.5449
# hoco           -5.5300
# beautiful!     -5.4840
# ️'s            -5.3194
# ️ve            -5.2155
#
# For tag:  ('💕', '_two_hearts_')
# 10 most important features:
# #sanfranciscoengagement…7.2321
# #lovealwaysyje 7.1157
# #pinkout       6.8321
# #clemonsstudio 6.4348
# #gorgeouswithin6.4348
# #licensedwaxers6.4348
# mychicobsession6.4348
# #599budgetbabe 6.4348
# #nanjer        6.4348
# rockridge,     6.4348
# 10 least important features:
# ️…             -7.5934
# ️              -7.1151
# ️️             -6.9111
# ️.             -6.3267
# #imwithher     -5.6194
# niggas         -5.4978
# #election2016  -5.3052
# #vote          -5.3020
# ️!             -5.2754
# mixtape        -5.1652
#
# For tag:  ('🔥', '_fire_')
# 10 most important features:
# #fuego         8.0705
# [#newmusic]    7.7670
# ★best          7.6935
# ★instant_classic7.6935
# ravi$hing      7.6935
# #onfire        7.6140
# go!■           7.5278
# #laflame       7.4334
# 'play          7.3291
# search.!       7.3291
# 10 least important features:
# ️…             -7.4964
# ️️             -6.8141
# ️              -6.4194
# ️.             -6.2297
# #imwithher     -5.5224
# much!          -5.4609
# sweetest       -5.2928
# adorable       -5.2467
# puppy          -5.2277
# ️!             -5.1784
#
# For tag:  ('😊', '_smiling_face_with_smiling_eyes_')
# 10 most important features:
# 7171           7.0959
# #dickensfranklin7.0959
# #dickensofachristmas7.0959
# (225)          6.9441
# #swagcity      6.9441
# 802-3037       6.9441
# #pembroke      6.9441
# #bestvocalgroup6.9441
# following!     6.7651
# #alltheirclassics6.7651
# 10 least important features:
# ️…             -7.4814
# ️              -6.8513
# ️️             -6.7992
# ️.             -6.2147
# ️!             -5.1634
# ️ny            -5.0227
# 9/11           -4.9669
# dat            -4.8947
# lmfao          -4.7480
# #facts         -4.6956
#
# For tag:  ('😎', '_smiling_face_with_sunglasses_')
# 10 most important features:
# elpaso_barfly  7.2378
# #beautique     7.0860
# #thebeardedfish…7.0860
# #ladyaphrodite 7.0860
# digg!          7.0860
# "reliving      7.0860
# #gotshadeonline6.9069
# rtparties      6.9069
# #vamoaltiro    6.9069
# #teamkr        6.9069
# 10 least important features:
# ️…             -7.3395
# ️              -7.0403
# ️️             -6.6573
# :…             -6.4472
# ️.             -6.0728
# christmas!     -5.2990
# ily            -5.2139
# ️!             -5.0216
# ️ny            -4.8808
# kisses         -4.8652
#
# For tag:  ('✨', '_sparkles_')
# 10 most important features:
# #getonshimmur  7.9456
# emle           7.5813
# #lashlife      7.4649
# -walt          7.4649
# #pinquotes…    7.4649
# #glambellastudio7.4649
# mmxvi          7.4649
# e-team         7.3331
# wish,          7.1813
# #makeupartist, 7.0022
# 10 least important features:
# ️              -10.8769
# ️…             -7.2442
# ️️             -6.5620
# ️.             -5.9775
# lmao           -5.6717
# father's       -5.4268
# #merica        -5.2164
# #election2016  -4.9561
# #vote          -4.9528
# ️!             -4.9263
#
# For tag:  ('💙', '_blue_heart_')
# 10 most important features:
# #autismspeaks  7.4301
# likefollow     7.4301
# #theei         7.2783
# #lightitupblue 7.2783
# twisters       7.2783
# #mpbtb         7.2783
# #weehawkenadventures7.2783
# #zetaphibeta   7.0992
# #icecreamlady#autismspeaks7.0992
# #gpsgirl!      7.0992
# 10 least important features:
# ️              -10.7799
# ️…             -7.1473
# ️️             -6.4650
# :…             -6.2549
# ️.             -5.8806
# christmas!     -5.1067
# dj             -5.0939
# niggas         -5.0517
# #christmastree -4.9674
# #foodie        -4.9644
#
# For tag:  ('😘', '_face_blowing_a_kiss_')
# 10 most important features:
# #princessmailyana7.4440
# #armenianbbq   6.8949
# #armorican     6.8949
# #armobbq       6.8949
# love...follow  6.8949
# carli's        6.6153
# instock        6.6153
# #followmecamerondallas6.6153
# #mzvib         6.6153
# beijo          6.6153
# 10 least important features:
# ️              -8.3681
# ️…             -7.1333
# ️️             -6.4511
# :…             -6.2410
# ️.             -5.8666
# #merica        -5.1055
# veterans       -5.0242
# #christmastree -4.9535
# ️!             -4.8153
# #hiphop        -4.7384
#
# For tag:  ('📷', '_camera_')
# 10 most important features:
# #bvillain      8.4006
# #shredforaliving!7.9441
# #gdlfashion    7.9441
# garcia)        7.8579
# spiro          7.6592
# #tfti_la       7.6592
# mandylor       7.5428
# #wildwintertour7.5428
# #sneakersaddict7.5428
# [workflowshxt] 7.4110
# 10 least important features:
# ️              -10.7990
# ️…             -7.1663
# ️️             -6.4841
# ️.             -5.8996
# #i             -5.7745
# bestie         -5.3529
# #merica        -5.1384
# boyfriend      -5.1359
# aquarium       -5.0841
# roomie         -5.0434
#
# For tag:  ('🇺🇸', '_United_States_')
# 10 most important features:
# #flag          9.1203
# #flagday       8.9955
# #unitedstatesofamerica8.4869
# #werewithher   8.4300
# #weremember    8.3698
# #proudtobeanamerican8.2371
# #americanflag  8.1636
# #veteransday20168.1636
# #everyvotecounts8.0842
# #civicduty     8.0842
# 10 least important features:
# ️              -10.6589
# ️…             -7.0263
# ️️             -6.3440
# ontario        -6.0825
# ️.             -5.7596
# #i             -5.6344
# nigga          -5.5394
# boo            -5.4360
# hospital       -5.4344
# toronto,       -5.3370
#
# For tag:  ('☀', '_sun_')
# 10 most important features:
# ️beach         7.6956
# floatin'       7.5638
# ️sunny         7.5638
# ️sun           7.4120
# ️#summer       7.4120
# 2016#photographer_serena7.2330
# rays!          7.2330
# #summertramp   7.2330
# ️--------------#iphone7.2330
# #hellosunshine 7.0147
# 10 least important features:
# wit            -5.4662
# rt             -5.3817
# phone          -5.1480
# purple         -5.1042
# vote           -5.0793
# #imwithher     -5.0395
# family.        -5.0348
# cutie          -5.0203
# #merica        -4.9856
# cheer          -4.9806
#
# For tag:  ('💜', '_purple_heart_')
# 10 most important features:
# pancreatic     7.7677
# #wagehope      7.7677
# asulin         7.6359
# #paisleypark   7.6359
# jewelryhandmade7.6359
# one-of-a-kind… 7.6359
# #purpledrink   7.3051
# chicora,       7.3051
# #thelongestday 7.0868
# #capfam        7.0868
# 10 least important features:
# ️              -10.5740
# ️…             -6.9414
# ️️             -6.2592
# :…             -6.0491
# ️.             -5.6747
# rt             -5.3096
# #merrychristmas-5.2099
# #merica        -4.9135
# niggas         -4.8458
# dropping       -4.7790
#
# For tag:  ('😉', '_winking_face_')
# 10 most important features:
# #mividaesunatombola7.5135
# azek…          7.3617
# #silvercriketgentlemensclub7.3617
# shoot!!!!model:7.3617
# multi-level    7.3617
# #wearfutbolers 7.1827
# style"⠀#futbolers7.1827
# "special       7.1827
# #mrmrsgillette 6.9644
# #wait4it2click 6.9644
# 10 least important features:
# ️              -8.2985
# ️…             -7.0638
# ️️             -6.3816
# ️.             -5.7971
# #merica        -5.0359
# #christmastree -4.8839
# peace          -4.7525
# ️!             -4.7458
# mixtape        -4.6356
# ️ny            -4.6051
#
# For tag:  ('💯', '_hundred_points_')
# 10 most important features:
# #t3t           8.0647
# #eclecticeatery7.9703
# #childrenofthekorn7.9703
# #keepit        7.9703
# #itsonlyrightent7.7496
# #vowork        7.7496
# #licensedbarber7.7496
# %…             7.7496
# #livefeed      7.6179
# s.o.s.         7.6179
# 10 least important features:
# ️…             -6.9594
# ️              -6.3293
# ️️             -6.2772
# ️.             -5.6927
# #disney        -5.3037
# fave           -5.0021
# cutie          -4.9662
# #merica        -4.9316
# much!          -4.9240
# christmas!     -4.9189
#
# For tag:  ('😁', '_beaming_face_with_smiling_eyes_')
# 10 most important features:
# strasberg      7.0347
# fcpx           7.0347
# paranormal     6.7552
# #gruvartist    6.7552
# log:           6.7552
# #appstate      6.7552
# #southparkmall…6.7552
# #godisable     6.7552
# do!!!!         6.7552
# #top40…        6.7552
# 10 least important features:
# ️              -7.5816
# ️…             -6.9935
# ️️             -6.3112
# :…             -6.1011
# ️.             -5.7268
# love!          -5.1842
# kappa          -4.9453
# ily            -4.8678
# hearts         -4.7563
# classic        -4.7118
#
# For tag:  ('🎄', '_Christmas_tree_')
# 10 most important features:
# #nationalchristmastree7.8111
# yuletide       7.6793
# flockcityla    7.5275
# objets         7.5275
# #chirstmas     7.5275
# #flockcity     7.5275
# sugargrove     7.3485
# decking        7.3485
# #lifechangers  7.3485
# #deckthehalls  7.3485
# 10 least important features:
# ️…             -6.8980
# ️              -6.4197
# ️️             -6.2158
# ️.             -5.6313
# prom           -5.6218
# #i             -5.5061
# fuck           -5.4257
# bitch          -5.2105
# makeup         -5.1027
# father's       -5.0805
#
# For tag:  ('📸', '_camera_with_flash_')
# 10 most important features:
# #grigsby       7.7186
# #mikeyshotya   7.5868
# #widthisguy…   7.5868
# #michaelgrigsby7.5868
# #grigsgang     7.5868
# #watarewegonnado7.5868
# soymaico       7.5868
# #thedstoneponyshow7.5868
# #soreadytobang 7.4350
# smartscott     7.4350
# 10 least important features:
# ️              -10.6231
# ️…             -6.9905
# ️️             -6.3082
# fl)            -5.8191
# ️.             -5.7238
# #i             -5.5986
# omg            -5.4227
# #happy         -5.2794
# phi            -5.1832
# elementary     -5.1377
#
# For tag:  ('😜', '_winking_face_with_tongue_')
# 10 most important features:
# #photography"  7.2890
# #makeover...   7.2890
# "#boudoir      7.2890
# koundinyasa    6.7911
# hambrick       6.7911
# #mixxedfit     6.7911
# #alobienbarbersandstylists6.7911
# valhalla,      6.7911
# #dsly          6.7911
# apartment!!!   6.7911
# 10 least important features:
# ️              -7.5456
# ️…             -6.9575
# ️️             -6.2753
# :…             -6.0652
# ️.             -5.6908
# #i             -5.5656
# rockefeller    -5.1761
# #imwithher     -4.9835
# #merica        -4.9296
# sweetest       -4.7539
#
# CPU times: user 12.8 s, sys: 421 ms, total: 13.2 s
# Wall time: 3.33 s
