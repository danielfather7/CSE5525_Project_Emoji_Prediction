# %%
import numpy as np
from scipy.sparse import csr_matrix
from sklearn.naive_bayes import MultinomialNB

from Emojidata import EMOJIdata

# %%
train = EMOJIdata("./data/us_train.text")
test = EMOJIdata("./data/us_test.text", vocab=train.vocab)

# %%
emojiMap = {}
for line in open("./data/us_mapping.txt"):
    line = line.split()    
    emojiMap[int(line[0])] = (line[1], line[2])
emojiMap
# Out:
# {0: ('❤', '_red_heart_'),
#  1: ('😍', '_smiling_face_with_hearteyes_'),
#  2: ('😂', '_face_with_tears_of_joy_'),
#  3: ('💕', '_two_hearts_'),
#  4: ('🔥', '_fire_'),
#  5: ('😊', '_smiling_face_with_smiling_eyes_'),
#  6: ('😎', '_smiling_face_with_sunglasses_'),
#  7: ('✨', '_sparkles_'),
#  8: ('💙', '_blue_heart_'),
#  9: ('😘', '_face_blowing_a_kiss_'),
#  10: ('📷', '_camera_'),
#  11: ('🇺🇸', '_United_States_'),
#  12: ('☀', '_sun_'),
#  13: ('💜', '_purple_heart_'),
#  14: ('😉', '_winking_face_'),
#  15: ('💯', '_hundred_points_'),
#  16: ('😁', '_beaming_face_with_smiling_eyes_'),
#  17: ('🎄', '_Christmas_tree_'),
#  18: ('📸', '_camera_with_flash_'),
#  19: ('😜', '_winking_face_with_tongue_')}

# %%
#baseline by most frequent tag
print("Most requent tag is: ", emojiMap[train.mostFreqLbl])
print("Baseline by most frequent tag: ", np.count_nonzero(test.Y == train.mostFreqLbl)/test.Y.shape[0])
# Out:
# Most requent tag is:  ('❤', '_red_heart_')
# Baseline by most frequent tag:  0.21596

# %%
#test on different value of alpha
for alpha in [0.01, 0.05, 0.1, 0.5, 1.0, 5.0, 10.0]:
    clf = MultinomialNB(alpha=alpha, fit_prior=True, class_prior=None)
    clf.fit(train.X, train.Y)
    print("Alpha = %.2f\tscore = %.5f" %(alpha, clf.score(test.X, test.Y)))
# Out:
# Alpha = 0.01	score = 0.36806
# Alpha = 0.05	score = 0.38478
# Alpha = 0.10	score = 0.38888
# Alpha = 0.50	score = 0.34890
# Alpha = 1.00	score = 0.30862
# Alpha = 5.00	score = 0.24102
# Alpha = 10.00	score = 0.23036

# %%
#find the important features by highest alpha
alpha = 0.1 #best performance
print("Emoji Prediction by Naive Bayes with alpha=", alpha)
clf = MultinomialNB(alpha=alpha, fit_prior=True, class_prior=None)
clf.fit(train.X, train.Y)
for i in range(clf.coef_.shape[0]):
    print("For tag: ", emojiMap[i])
    coefSorted = np.argsort(clf.feature_log_prob_[i])
    print("10 most important features: ")
    for coefid in coefSorted[-1:-11:-1]:
        print("{:<15}{:>.4f}".format(train.vocab.GetWord(coefid), clf.coef_[i][coefid]))
    print("10 least important features: ")
    for coefid in coefSorted[:10]:
        print("{:<15}{:>.4f}".format(train.vocab.GetWord(coefid), clf.coef_[i][coefid]))
    print()
# Out:
# Emoji Prediction by Naive Bayes with alpha= 0.1
# For tag:  ('❤', '_red_heart_')
# 10 most important features:
# ️              -2.5937
# @              -3.0097
# the            -3.8616
# my             -3.9121
# @user          -4.1895
# i              -4.2684
# to             -4.3203
# with           -4.5024
# love           -4.5441
# and            -4.5742
# 10 least important features:
# v'             -16.4123
# "friday"       -16.4123
# hubspot        -16.4123
# cereal,        -16.4123
# #meateaters    -16.4123
# #setitandforgetit-16.4123
# #slabbedup     -16.4123
# cedarburg,     -16.4123
# #newyorkyankees-16.4123
# #bronxbombers  -16.4123
#
# For tag:  ('😍', '_smiling_face_with_hearteyes_')
# 10 most important features:
# @              -3.0727
# the            -3.8102
# @user          -4.0322
# my             -4.1167
# i              -4.3815
# to             -4.4139
# in             -4.4493
# this           -4.5458
# a              -4.5464
# and            -4.5810
# 10 least important features:
# v'             -15.6411
# #theandrewsadventures…-15.6411
# #echostagedc   -15.6411
# ----#scotch    -15.6411
# lol)now        -15.6411
# i-d,           -15.6411
# #thanksmom…    -15.6411
# #youmattertome -15.6411
# ️️#waitressmusical-15.6411
# c2e2           -15.6411
#
# For tag:  ('😂', '_face_with_tears_of_joy_')
# 10 most important features:
# @              -3.3996
# the            -3.7654
# @user          -3.8553
# i              -3.9954
# to             -4.2231
# a              -4.2774
# my             -4.4423
# this           -4.5830
# in             -4.6771
# and            -4.6926
# 10 least important features:
# v'             -15.6855
# #mileyroundtwo -15.6855
# awesomeuse     -15.6855
# cashmere@thejbieberwife-15.6855
# chopburlap     -15.6855
# development,   -15.6855
# lantern!       -15.6855
# havasupai      -15.6855
# ......#merrychristmas-15.6855
# #jackastorssquare1-15.6855
#
# For tag:  ('💕', '_two_hearts_')
# 10 most important features:
# @              -2.9648
# my             -3.8715
# the            -3.8724
# to             -4.2500
# with           -4.3485
# i              -4.4193
# @user          -4.4338
# you            -4.4823
# love           -4.5652
# a              -4.5874
# 10 least important features:
# v'             -15.0906
# #whodressedus… -15.0906
# 110th          -15.0906
# zander_x       -15.0906
# #bolt68        -15.0906
# #bomberg       -15.0906
# #luxedesigns   -15.0906
# samb's         -15.0906
# fernandos      -15.0906
# somllll        -15.0906
#
# For tag:  ('🔥', '_fire_')
# 10 most important features:
# @              -3.2710
# @user          -3.4746
# the            -3.7435
# to             -4.5336
# in             -4.7153
# on             -4.7676
# is             -4.8204
# my             -4.8493
# and            -4.8916
# a              -4.9064
# 10 least important features:
# v'             -14.9993
# corrales,      -14.9993
# glorioso       -14.9993
# #outletpremium…-14.9993
# #10pm          -14.9993
# #larabeestatepark-14.9993
# #seattleday    -14.9993
# #hamilzin      -14.9993
# gettysburg,…   -14.9993
# matan          -14.9993
#
# For tag:  ('😊', '_smiling_face_with_smiling_eyes_')
# 10 most important features:
# @              -3.3504
# the            -3.8843
# @user          -4.1312
# to             -4.1919
# a              -4.2750
# my             -4.3638
# i              -4.5138
# in             -4.5261
# and            -4.5746
# for            -4.6663
# 10 least important features:
# v'             -14.9852
# #sinceihadntcookedsince96-14.9852
# 2:28am         -14.9852
# dre1o1_        -14.9852
# ️#followhim    -14.9852
# #arvermont2016 -14.9852
# #notaleafatethat-14.9852
# #stowevt       -14.9852
# eejits.…       -14.9852
# #superbowlweekend,-14.9852
#
# For tag:  ('😎', '_smiling_face_with_sunglasses_')
# 10 most important features:
# @              -3.0790
# the            -3.7760
# @user          -4.2352
# a              -4.4479
# to             -4.4971
# in             -4.4999
# my             -4.7590
# and            -4.8500
# i              -4.8814
# of             -4.8969
# 10 least important features:
# millenarium    -14.8507
# hwoodphotoart!!-14.8507
# #5thward       -14.8507
# #englishmuffin -14.8507
# #americanpie   -14.8507
# #missmyhusband -14.8507
# stokoe         -14.8507
# #thecastofcats -14.8507
# #deadlyzoo     -14.8507
# #tdzp          -14.8507
#
# For tag:  ('✨', '_sparkles_')
# 10 most important features:
# @              -3.1416
# the            -3.7298
# @user          -4.3576
# a              -4.4008
# to             -4.4382
# of             -4.5806
# and            -4.7683
# in             -4.7761
# my             -4.8508
# i              -4.9018
# 10 least important features:
# v'             -14.7598
# us.a           -14.7598
# #yorkyterrier… -14.7598
# #yorkylove     -14.7598
# woofyou!       -14.7598
# mommy....      -14.7598
# gooooooo!!!!   -14.7598
# leeeeeetsss    -14.7598
# #austinweddingplanner…-14.7598
# #a2clemons     -14.7598
#
# For tag:  ('💙', '_blue_heart_')
# 10 most important features:
# @              -2.9942
# the            -3.9671
# my             -4.1271
# to             -4.4262
# @user          -4.5419
# i              -4.5782
# with           -4.7295
# a              -4.7353
# of             -4.7475
# you            -4.7975
# 10 least important features:
# v'             -14.6669
# won!!!!!       -14.6669
# year......and  -14.6669
# #germanypavillion…-14.6669
# #snowwhiteswishingwell-14.6669
# #jankrx…       -14.6669
# #dirtpartygarage-14.6669
# #dirtpartygarageofficials-14.6669
# #fc3s          -14.6669
# #imboulder…    -14.6669
#
# For tag:  ('😘', '_face_blowing_a_kiss_')
# 10 most important features:
# @              -3.1765
# @user          -3.9664
# the            -4.0644
# my             -4.1132
# you            -4.1879
# to             -4.3284
# i              -4.5265
# for            -4.5879
# with           -4.5960
# love           -4.6221
# 10 least important features:
# v'             -14.6536
# #reggioemilia… -14.6536
# #reggio        -14.6536
# eat...oh       -14.6536
# sclerosis.     -14.6536
# victors!!!     -14.6536
# vicki's        -14.6536
# #mysweetfriends-14.6536
# #postcards     -14.6536
# #holidaysarecoming-14.6536
#
# For tag:  ('📷', '_camera_')
# 10 most important features:
# @user          -3.0650
# @              -3.3477
# :              -3.7232
# the            -3.8396
# a              -4.6162
# to             -4.7463
# in             -4.7907
# of             -4.7983
# by             -4.9753
# for            -5.0295
# 10 least important features:
# v'             -14.6852
# “@causewereglrls:-14.6852
# do?!"-steve#cowabunga…-14.6852
# laughed!       -14.6852
# worried...     -14.6852
# #theleavesarechanging…-14.6852
# #olivepark     -14.6852
# frozed!        -14.6852
# #saturdayinthecity-14.6852
# #phillyphood   -14.6852
#
# For tag:  ('🇺🇸', '_United_States_')
# 10 most important features:
# @              -3.0259
# the            -3.8677
# to             -4.5935
# of             -4.6121
# @user          -4.6460
# in             -4.6525
# and            -4.8942
# #usa           -4.9234
# a              -4.9748
# new            -5.0144
# 10 least important features:
# v'             -14.5506
# pensacola,…    -14.5506
# #ekfit…        -14.5506
# #puffdamagicdragon-14.5506
# #countryclub   -14.5506
# #k$            -14.5506
# #italianstalion-14.5506
# #knitwear…     -14.5506
# #hhd           -14.5506
# #hoodieponch   -14.5506
#
# For tag:  ('☀', '_sun_')
# 10 most important features:
# ️              -2.7106
# @              -3.0285
# the            -3.8420
# a              -4.5367
# in             -4.6342
# beach          -4.6781
# to             -4.6876
# day            -4.9237
# and            -4.9772
# of             -5.0411
# 10 least important features:
# v'             -14.5382
# one_goal_to_get-14.5382
# rockport…      -14.5382
# rez,           -14.5382
# buddy•         -14.5382
# #downloadmyshitmane…-14.5382
# #usherdem      -14.5382
# #luckyybam     -14.5382
# #mobitchesthanusherdem-14.5382
# accio          -14.5382
#
# For tag:  ('💜', '_purple_heart_')
# 10 most important features:
# @              -3.1476
# the            -4.0756
# my             -4.1188
# @user          -4.3958
# to             -4.3979
# i              -4.5026
# with           -4.7406
# you            -4.7412
# a              -4.7424
# of             -4.7851
# 10 least important features:
# v'             -14.4686
# “@bestflghts:  -14.4686
# #loglife…      -14.4686
# #missmyfamiry  -14.4686
# ...#latepost   -14.4686
# dtran_89       -14.4686
# trabajar       -14.4686
# #hitchedtohansen-14.4686
# marianhillmusic-14.4686
# gongol         -14.4686
#
# For tag:  ('😉', '_winking_face_')
# 10 most important features:
# @              -3.5145
# the            -3.8982
# a              -4.2570
# @user          -4.2741
# to             -4.3414
# i              -4.5097
# in             -4.6963
# you            -4.6983
# my             -4.7611
# for            -4.7980
# 10 least important features:
# v'             -14.5867
# hint!!…        -14.5867
# newyork.ballet -14.5867
# performanced   -14.5867
# #latinofest    -14.5867
# lightboxer     -14.5867
# #peabodysvb    -14.5867
# thenine10      -14.5867
# big-mouth-phil -14.5867
# boogs          -14.5867
#
# For tag:  ('💯', '_hundred_points_')
# 10 most important features:
# @              -3.2688
# the            -3.9302
# @user          -4.1126
# to             -4.4652
# my             -4.6583
# i              -4.6697
# a              -4.7865
# you            -4.8924
# and            -4.9285
# in             -4.9905
# 10 least important features:
# v'             -14.4861
# chicagobulls#bullswin-14.4861
# ️#lacmalights  -14.4861
# lacma.         -14.4861
# #ralphie       -14.4861
# ho-ey          -14.4861
# •••proud       -14.4861
# 5.55           -14.4861
# ...#wedding    -14.4861
# #citruspressco -14.4861
#
# For tag:  ('😁', '_beaming_face_with_smiling_eyes_')
# 10 most important features:
# @              -3.4711
# the            -3.9932
# @user          -4.1934
# to             -4.3604
# a              -4.4674
# in             -4.4787
# i              -4.5501
# my             -4.6045
# and            -4.8273
# for            -4.9031
# 10 least important features:
# v'             -14.5189
# intentionz     -14.5189
# sayed          -14.5189
# #coolmomsclubsf-14.5189
# rivet,         -14.5189
# #ecuadorian    -14.5189
# #kflay         -14.5189
# vol.3"         -14.5189
# kosher!        -14.5189
# broccoli.      -14.5189
#
# For tag:  ('🎄', '_Christmas_tree_')
# 10 most important features:
# @              -3.0666
# christmas      -3.4958
# the            -3.6447
# a              -4.5043
# to             -4.5291
# merry          -4.6481
# of             -4.7563
# @user          -4.8276
# and            -4.8783
# in             -4.9228
# 10 least important features:
# v'             -14.4266
# glutten        -14.4266
# is....in       -14.4266
# #ourhappyplace -14.4266
# #weloveithere  -14.4266
# lucid          -14.4266
# mya_masica     -14.4266
# naaaahhhhh     -14.4266
# helllll        -14.4266
# "@taywest:     -14.4266
#
# For tag:  ('📸', '_camera_with_flash_')
# 10 most important features:
# @user          -3.1240
# @              -3.3297
# the            -3.8704
# :              -3.9122
# a              -4.6140
# to             -4.7068
# of             -4.8995
# in             -4.9543
# by             -5.0371
# i              -5.1393
# 10 least important features:
# v'             -14.5161
# whaaaaattt!!!!!-14.5161
# 1-35           -14.5161
# #signingday    -14.5161
# #drakecrew     -14.5161
# #drakeuniversity-14.5161
# #instautah…    -14.5161
# evelbunny      -14.5161
# styers         -14.5161
# creativeness   -14.5161
#
# For tag:  ('😜', '_winking_face_with_tongue_')
# 10 most important features:
# @              -3.3752
# the            -3.9663
# @user          -4.3954
# a              -4.4160
# to             -4.4678
# i              -4.5628
# my             -4.6570
# in             -4.7228
# and            -4.9001
# for            -4.9893
# 10 least important features:
# v'             -14.4842
# #christmassongs-14.4842
# #nextlevel     -14.4842
# "@cantbehandled_:-14.4842
# d'youville     -14.4842
# #clarevivier   -14.4842
# #cvambassador  -14.4842
# #milkyway…     -14.4842
# ahren          -14.4842
# #thedictator   -14.4842

# %%
train = EMOJIdata("./data/us_train_stripped.text")
test = EMOJIdata("./data/us_test_stripped.text", vocab=train.vocab)

# %%
#test on different value of alpha
for alpha in [0.01, 0.05, 0.1, 0.5, 1.0, 5.0, 10.0]:
    clf = MultinomialNB(alpha=alpha, fit_prior=True, class_prior=None)
    clf.fit(train.X, train.Y)
    print("Alpha = %.2f\tscore = %.5f" %(alpha, clf.score(test.X, test.Y)))
# Out:
# Alpha = 0.01	score = 0.28272
# Alpha = 0.05	score = 0.29720
# Alpha = 0.10	score = 0.30518
# Alpha = 0.50	score = 0.30780
# Alpha = 1.00	score = 0.29102
# Alpha = 5.00	score = 0.25048
# Alpha = 10.00	score = 0.24016

# %%
#find the important features by highest alpha
alpha = 0.1 #best performance
print("Emoji Prediction by Naive Bayes with alpha=", alpha)
clf = MultinomialNB(alpha=alpha, fit_prior=True, class_prior=None)
clf.fit(train.X, train.Y)
for i in range(clf.coef_.shape[0]):
    print("For tag: ", emojiMap[i])
    coefSorted = np.argsort(clf.coef_[i])
    print("10 most important features: ")
    for coefid in coefSorted[-1:-11:-1]:
        print("{:<15}{:>.4f}".format(train.vocab.GetWord(coefid), clf.coef_[i][coefid]))
    print("10 least important features: ")
    for coefid in coefSorted[:10]:
        print("{:<15}{:>.4f}".format(train.vocab.GetWord(coefid), clf.coef_[i][coefid]))
    print()
# Out:
# Emoji Prediction by Naive Bayes with alpha= 0.1
# For tag:  ('❤', '_red_heart_')
# 10 most important features:
# user           -3.6587
# love           -3.8191
# the            -4.5697
# happy          -4.7102
# new            -4.8344
# amp            -4.9301
# day            -5.0240
# best           -5.2249
# birthday       -5.3406
# family         -5.3644
# 10 least important features:
# kuchar         -15.8815
# smilingforever -15.8815
# smilingforthecamera-15.8815
# gypsystone     -15.8815
# judokarate     -15.8815
# nnkvoting      -15.8815
# democracyinaction-15.8815
# zekepapi       -15.8815
# iamcreative    -15.8815
# xnilax         -15.8815
#
# For tag:  ('😍', '_smiling_face_with_hearteyes_')
# 10 most important features:
# user           -3.6000
# love           -4.3480
# the            -4.5140
# new            -4.7643
# amp            -5.0492
# beautiful      -5.2571
# day            -5.4069
# today          -5.4869
# this           -5.5008
# night          -5.5430
# 10 least important features:
# kuchar         -15.2089
# zeroheyes      -15.2089
# suzolm         -15.2089
# geraldgillum   -15.2089
# vonbarnyc      -15.2089
# gbatokai       -15.2089
# slingin        -15.2089
# repostappcoming-15.2089
# purejoypeople  -15.2089
# feelingalittlekarencarpenterchristmas-15.2089
#
# For tag:  ('😂', '_face_with_tears_of_joy_')
# 10 most important features:
# user           -3.3635
# the            -4.8388
# like           -5.0430
# lol            -5.0453
# new            -5.2400
# when           -5.2462
# got            -5.2709
# this           -5.3038
# get            -5.4272
# amp            -5.4364
# 10 least important features:
# millenarium    -15.1937
# electriccolorbar-15.1937
# electriccb     -15.1937
# tysinger       -15.1937
# fshnbnkr       -15.1937
# thekategatsby  -15.1937
# semco          -15.1937
# newyearnewyork -15.1937
# guerin         -15.1937
# noodlesoup     -15.1937
#
# For tag:  ('💕', '_two_hearts_')
# 10 most important features:
# user           -3.9579
# love           -3.9683
# happy          -4.6337
# the            -4.6884
# best           -4.9589
# amp            -4.9686
# day            -5.0529
# new            -5.1138
# university     -5.2111
# birthday       -5.2438
# 10 least important features:
# kuchar         -14.6147
# thevisualartist-14.6147
# proposing      -14.6147
# summerdreaming -14.6147
# ᴬᴸᴹᴼˢᵀ         -14.6147
# ᵀᴵᴵᴵᴵᴹᴱ        -14.6147
# soufside       -14.6147
# saluteda       -14.6147
# fyre           -14.6147
# nei            -14.6147
#
# For tag:  ('🔥', '_fire_')
# 10 most important features:
# user           -3.0460
# the            -4.3839
# lit            -4.4485
# new            -4.5615
# fire           -4.9496
# night          -4.9902
# tonight        -5.0580
# amp            -5.0610
# last           -5.3415
# this           -5.3949
# 10 least important features:
# kuchar         -14.5708
# rawneworleans  -14.5708
# ksa            -14.5708
# funy           -14.5708
# الرياض         -14.5708
# funprebday     -14.5708
# moorish        -14.5708
# khearn         -14.5708
# funwithmygrandson-14.5708
# findcleaning   -14.5708
#
# For tag:  ('😊', '_smiling_face_with_smiling_eyes_')
# 10 most important features:
# user           -3.6632
# happy          -4.7886
# day            -4.8500
# the            -4.9209
# new            -5.0498
# today          -5.0852
# good           -5.0917
# love           -5.1532
# amp            -5.1653
# time           -5.3644
# 10 least important features:
# kuchar         -14.5172
# ohnevermind    -14.5172
# spacecase      -14.5172
# lanai          -14.5172
# pyleoflove     -14.5172
# brothering     -14.5172
# elnig          -14.5172
# mattkraker     -14.5172
# theautumnatic  -14.5172
# alia           -14.5172
#
# For tag:  ('😎', '_smiling_face_with_sunglasses_')
# 10 most important features:
# user           -3.7983
# the            -4.6902
# beach          -4.8736
# new            -4.9443
# day            -5.0347
# amp            -5.2330
# good           -5.4130
# time           -5.6070
# today          -5.6085
# park           -5.6672
# 10 least important features:
# kuchar         -14.4140
# bernardbuffet  -14.4140
# mdempsey       -14.4140
# jzionce        -14.4140
# saturdaybrunch -14.4140
# ifam           -14.4140
# ncaafootball   -14.4140
# sicembears     -14.4140
# baylorfootball -14.4140
# nycig          -14.4140
#
# For tag:  ('✨', '_sparkles_')
# 10 most important features:
# user           -3.9001
# the            -4.5553
# new            -4.5899
# amp            -5.0749
# magic          -5.1223
# disney         -5.1719
# night          -5.3544
# day            -5.4203
# york           -5.4342
# love           -5.4442
# 10 least important features:
# kuchar         -14.3022
# goeeey         -14.3022
# miatagang      -14.3022
# seanfalyon     -14.3022
# allvinyleverything-14.3022
# stiltwalker    -14.3022
# mommmmm        -14.3022
# littlewhitechapel-14.3022
# drivethrou     -14.3022
# porcinet       -14.3022
#
# For tag:  ('💙', '_blue_heart_')
# 10 most important features:
# user           -4.0842
# love           -4.3289
# the            -4.8253
# happy          -5.0225
# day            -5.1102
# amp            -5.1489
# new            -5.1594
# beach          -5.2724
# best           -5.4027
# university     -5.4117
# 10 least important features:
# kuchar         -14.2097
# momentchildren -14.2097
# grownkids      -14.2097
# keno           -14.2097
# denverbiscuitcompany-14.2097
# ugavsgt        -14.2097
# shufffle       -14.2097
# theindylionel  -14.2097
# fromtheotherside-14.2097
# repostappgypsea-14.2097
#
# For tag:  ('😘', '_face_blowing_a_kiss_')
# 10 most important features:
# user           -3.5035
# love           -4.0375
# happy          -4.3803
# birthday       -4.8405
# the            -4.8457
# thanks         -4.9507
# day            -5.1069
# new            -5.1762
# amp            -5.2083
# thank          -5.3326
# 10 least important features:
# kuchar         -14.1907
# frisson        -14.1907
# knickknackshop -14.1907
# gitchee        -14.1907
# redsindoor     -14.1907
# wheninaustin   -14.1907
# bossbitchquotes-14.1907
# cleanairmoms   -14.1907
# cleanairkids   -14.1907
# grizrocks      -14.1907
#
# For tag:  ('📷', '_camera_')
# 10 most important features:
# user           -2.6161
# the            -4.7127
# new            -4.9753
# amp            -5.4145
# day            -5.5169
# york           -5.6627
# night          -5.6722
# park           -5.6992
# photo          -5.7170
# last           -5.7413
# 10 least important features:
# kuchar         -14.2364
# homiezlife     -14.2364
# haphaphappy    -14.2364
# betdiceweekend -14.2364
# votevotevote   -14.2364
# teamlv         -14.2364
# shopavocadoactivewear-14.2364
# shopavocado    -14.2364
# backgroundvocals-14.2364
# sojam          -14.2364
#
# For tag:  ('🇺🇸', '_United_States_')
# 10 most important features:
# usa            -4.1809
# user           -4.2406
# new            -4.5542
# the            -4.5756
# york           -4.8549
# america        -4.8698
# day            -4.8926
# nyc            -5.1603
# vote           -5.1704
# happy          -5.4224
# 10 least important features:
# kuchar         -14.1451
# iknowyoumissedmyface-14.1451
# lakechabot     -14.1451
# laisbacchi     -14.1451
# candyplease    -14.1451
# koreangummies  -14.1451
# hunnyyyy       -14.1451
# volviending    -14.1451
# metrotime      -14.1451
# cortlandtst    -14.1451
#
# For tag:  ('☀', '_sun_')
# 10 most important features:
# beach          -3.7487
# day            -4.2032
# user           -4.5786
# summer         -4.6493
# morning        -4.7949
# sun            -4.8582
# the            -4.8655
# good           -4.9071
# florida        -4.9269
# park           -5.0054
# 10 least important features:
# kuchar         -14.0320
# leoma          -14.0320
# lovegrove      -14.0320
# iwillletyouknowwheniamintown-14.0320
# americanlovetour-14.0320
# lifestyleztours-14.0320
# aaliyahbrumfield-14.0320
# pizanos        -14.0320
# pizano         -14.0320
# txgl           -14.0320
#
# For tag:  ('💜', '_purple_heart_')
# 10 most important features:
# user           -3.9302
# love           -4.2144
# the            -4.8555
# happy          -4.9551
# amp            -5.1365
# new            -5.2658
# day            -5.3101
# best           -5.3338
# university     -5.3373
# birthday       -5.6341
# 10 least important features:
# kuchar         -14.0031
# quickers       -14.0031
# avakingame     -14.0031
# alipoo         -14.0031
# brightleaf     -14.0031
# takemejusttocomplimentthedeal-14.0031
# imakehimlookgood-14.0031
# myteamclutch   -14.0031
# feelingallblack-14.0031
# wbf            -14.0031
#
# For tag:  ('😉', '_winking_face_')
# 10 most important features:
# user           -3.7836
# the            -4.9381
# new            -5.1550
# amp            -5.3043
# day            -5.4219
# good           -5.4479
# one            -5.5416
# like           -5.5571
# happy          -5.5650
# get            -5.6775
# 10 least important features:
# kuchar         -14.0962
# fusednola      -14.0962
# thenoladancers -14.0962
# brogue         -14.0962
# siezetheday    -14.0962
# makeitagreatday-14.0962
# positivevibe   -14.0962
# thenewstance   -14.0962
# manhattanlife  -14.0962
# mischiefmakers -14.0962
#
# For tag:  ('💯', '_hundred_points_')
# 10 most important features:
# user           -3.6474
# the            -4.6561
# new            -5.1197
# amp            -5.2215
# got            -5.5402
# day            -5.5718
# love           -5.5761
# university     -5.6851
# get            -5.7093
# real           -5.7597
# 10 least important features:
# kuchar         -14.0210
# lourson        -14.0210
# manathan       -14.0210
# foamposites    -14.0210
# sneakercon     -14.0210
# experiencedhunterforhire-14.0210
# mommasaysknockyouout-14.0210
# treets         -14.0210
# abmbeentrill   -14.0210
# welksresort    -14.0210
#
# For tag:  ('😁', '_beaming_face_with_smiling_eyes_')
# 10 most important features:
# user           -3.7222
# the            -4.9253
# new            -5.0215
# day            -5.2144
# amp            -5.3618
# today          -5.3892
# happy          -5.4173
# time           -5.4574
# got            -5.5904
# good           -5.7242
# 10 least important features:
# kuchar         -14.0480
# oneyearanniversary-14.0480
# mondaywine     -14.0480
# ggforever      -14.0480
# meadventures   -14.0480
# trumpvshillary -14.0480
# boruto         -14.0480
# ohmcultureyoga -14.0480
# nayefzarrour   -14.0480
# justnatalieok  -14.0480
#
# For tag:  ('🎄', '_Christmas_tree_')
# 10 most important features:
# christmas      -2.7966
# merry          -4.1783
# tree           -4.3871
# user           -4.3918
# the            -4.6520
# time           -5.1285
# happy          -5.1914
# holiday        -5.2730
# holidays       -5.2962
# family         -5.3097
# 10 least important features:
# kuchar         -13.9909
# zaynsaurus     -13.9909
# drasticmeasures-13.9909
# reymundough    -13.9909
# arverne        -13.9909
# timcurry       -13.9909
# susanlovesjack -13.9909
# mrukisboth     -13.9909
# kalikadiddlehopper-13.9909
# tacosunday     -13.9909
#
# For tag:  ('📸', '_camera_with_flash_')
# 10 most important features:
# user           -2.6700
# the            -4.7526
# new            -4.9737
# photo          -5.5093
# amp            -5.5307
# york           -5.6389
# day            -5.6747
# park           -5.7406
# night          -5.7553
# california     -5.7627
# 10 least important features:
# kuchar         -14.0620
# mattmcqueeny   -14.0620
# hiiigheye      -14.0620
# ortons         -14.0620
# niiiiice       -14.0620
# doublehead     -14.0620
# twod           -14.0620
# crossfitproper -14.0620
# uzbekstyle     -14.0620
# emazinglights  -14.0620
#
# For tag:  ('😜', '_winking_face_with_tongue_')
# 10 most important features:
# user           -3.9216
# the            -4.9484
# new            -5.2446
# amp            -5.2974
# day            -5.3258
# night          -5.6602
# good           -5.6625
# time           -5.7086
# happy          -5.7211
# like           -5.7414
# 10 least important features:
# kuchar         -14.0104
# montagemountain-14.0104
# goodpop        -14.0104
# mattapan       -14.0104
# vintagequest   -14.0104
# divalasvegas   -14.0104
# letsgetkrup    -14.0104
# thaibotiestheknot-14.0104
# tombradleyinternationalterminal-14.0104
# guerrillagirls -14.0104

# %%
from sklearn.svm import LinearSVC

# %%
clf = LinearSVC(random_state=0, tol=1e-5)

# %%
clf.fit(train.X, train.Y)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=0, tol=1e-05, verbose=0)

# %%
for i in range(clf.coef_.shape[0]):
    print("For tag: ", emojiMap[i])
    coefSorted = np.argsort(clf.coef_[i])
    print("10 most important features: ")
    for coefid in coefSorted[-1:-11:-1]:
        print("{:<15}{:>.4f}".format(train.vocab.GetWord(coefid), clf.coef_[i][coefid]))
    print("10 least important features: ")
    for coefid in coefSorted[:10]:
        print("{:<15}{:>.4f}".format(train.vocab.GetWord(coefid), clf.coef_[i][coefid]))
    print()
# Out:
# For tag:  ('❤', '_red_heart_')
# 10 most important features:
# #matchingneonpinkpants3.8588
# carvings       3.1957
# tulocay        3.1368
# #usteam        2.7261
# venus,         2.6703
# deary...       2.5863
# elevationuptown2.4460
# #watersunsets  2.4335
# feeler         2.4329
# alabama?"      2.4270
# 10 least important features:
# filter!!       -10.5073
# golsa          -10.5073
# chocolatey-date-9.6249
# rasors.        -8.1100
# toasty         -7.8548
# ️#ekbinteriors…-7.7005
# colors!!!!     -7.7005
# steinhardt,    -6.3195
# (boardwalk),   -6.3085
# ️...#chicago   -5.9260
#
# For tag:  ('😍', '_smiling_face_with_hearteyes_')
# 10 most important features:
# hawi           2.2745
# laila's        2.2490
# l_ratz8615     2.2212
# #forher        2.1581
# renee's        2.1235
# hallsontheriver2.0501
# #traveltips    1.9334
# tholos         1.8982
# coe…           1.8940
# #jhonniblaze   1.8861
# 10 least important features:
# ️              -2.3413
# ️…             -1.8515
# ️!             -1.6816
# espresso!      -1.5511
# #lifeamplifiedworldtour…-1.5211
# ️my            -1.5186
# pray…          -1.4924
# gotten.        -1.4908
# ️.             -1.4855
# #mancrushmonday…-1.4766
#
# For tag:  ('😂', '_face_with_tears_of_joy_')
# 10 most important features:
# week..!        3.5868
# "@autocorrects:3.1125
# #liveloveshine 2.7574
# treats,…       2.1821
# florida:       2.0496
# b93.7…         2.0199
# #chirp         1.9934
# #stillstuckonwestcoasttime…1.9934
# #postavideoyoucantexplain1.9898
# ash.arbaugh    1.9528
# 10 least important features:
# #related       -2.2074
# parked,        -2.1626
# want.          -2.1507
# torey          -1.9669
# #dogsofig…     -1.9317
# ️…             -1.9136
# xd…            -1.8605
# #nightout…     -1.8527
# mind…          -1.8516
# berea,         -1.8385
#
# For tag:  ('💕', '_two_hearts_')
# 10 most important features:
# #lalahhathaway 2.2464
# #littleghettoboy2.2464
# #favoriteguyintheworld2.1757
# #weddeddayfunners2.1757
# ephelpsnyc     1.9311
# love?hoodie    1.8545
# asballet       1.8303
# thrifting      1.8290
# #ivoryperkinsbeauty…1.8215
# #honeybglam    1.8141
# 10 least important features:
# ️              -2.0311
# lazy…          -1.7920
# ️…             -1.6001
# #thebachelor   -1.5337
# lovetts        -1.4035
# moons          -1.4000
# go....         -1.3917
# ️️             -1.3638
# moniiiiii      -1.3574
# #limestonenation-1.3424
#
# For tag:  ('🔥', '_fire_')
# 10 most important features:
# wings!!!!!     4.8443
# mavado         2.6911
# #statestreetsandpresidents2.3616
# forcepresented 2.1296
# fact…          2.0870
# (i've          2.0238
# n7             1.9781
# #joytotheworld…1.9491
# from...?!#thiscrowdisonfire1.9216
# #fire          1.9100
# 10 least important features:
# nocturnal      -2.3440
# dentist        -2.2315
# helloitmelou   -2.0732
# mysteries.     -1.9771
# #goals2k17     -1.9646
# direalshaggy   -1.9581
# #truestory     -1.9082
# cool:          -1.8957
# #allseptember  -1.8369
# #tonyrobbins2016…-1.7633
#
# For tag:  ('😊', '_smiling_face_with_smiling_eyes_')
# 10 most important features:
# clutched       2.2913
# #lilmama       1.9068
# heschasingthesun1.8330
# playbill       1.8219
# blessed?       1.7242
# #tutorial      1.7041
# #britishboy…   1.6935
# sphwiggs       1.6745
# #imsobasic     1.6590
# #werematijcios 1.6572
# 10 least important features:
# ️…             -1.5705
# butte.         -1.5486
# ️              -1.3717
# someone's…     -1.3127
# ️.             -1.2659
# airplane,      -1.2630
# hate,          -1.2249
# #janome        -1.2211
# robby          -1.2045
# trap!          -1.1876
#
# For tag:  ('😎', '_smiling_face_with_sunglasses_')
# 10 most important features:
# sandtrooper    2.2302
# .from          2.0635
# jimmy-truck    1.9206
# #mtts2016...   1.9058
# #zillionaire   1.8508
# #styledbymiked 1.8448
# #theblockbham  1.8358
# #cruisetime    1.8165
# at!"           1.7728
# ..#monday      1.7664
# 10 least important features:
# ️              -1.6492
# #dittopoolside…-1.5009
# slavic         -1.3941
# details:…      -1.2933
# :…             -1.2413
# elevator.      -1.2235
# wings,         -1.2140
# sparks         -1.2050
# #maintenancecommingsoon-1.1849
# motherfucking  -1.1777
#
# For tag:  ('✨', '_sparkles_')
# 10 most important features:
# pennsbury      1.8433
# #nationscapital…1.8227
# flawed.        1.7903
# conorado       1.7857
# #wingardiumleviosa1.7695
# tokslabossmua  1.7669
# 05.08.15       1.7631
# today.•repetition1.7613
# #getonshimmur  1.7471
# shoppe...reminds1.7448
# 10 least important features:
# ️              -2.2594
# nicholas       -2.2562
# ️…             -1.8066
# "light,        -1.6997
# dust,          -1.5087
# walt,          -1.4639
# ️.             -1.4559
# place&amp;more -1.4460
# weren't        -1.4411
# privateeditorial-1.3711
#
# For tag:  ('💙', '_blue_heart_')
# 10 most important features:
# crafton        1.8431
# hope4insight   1.7819
# lisalandy_     1.7803
# #gettingshittywithcritti1.7716
# ved            1.7558
# #pagebeauty…   1.7539
# #weehawkenadventures1.7479
# blueberries    1.7359
# sadness,       1.7221
# #kahanu        1.7214
# 10 least important features:
# ️              -2.3600
# christ,        -1.6361
# discount**…    -1.5575
# #rangersscoreboard-1.4826
# boulder        -1.4244
# ️️             -1.4186
# cove…          -1.3891
# ️…             -1.3476
# undisputed     -1.3239
# stadium-kansas -1.3171
#
# For tag:  ('😘', '_face_blowing_a_kiss_')
# 10 most important features:
# #lovelivelaugh 1.8598
# garrettsville, 1.7994
# china_1990     1.7965
# delgrosso's    1.7651
# single)        1.7518
# #islandwidepsychicfairs1.7122
# ait            1.6749
# #greatsanddunes…1.6687
# #berwickgirls… 1.6661
# #snapconf      1.6644
# 10 least important features:
# ️              -2.0300
# ️…             -1.6519
# ivan           -1.3903
# beech…         -1.3336
# later!         -1.2860
# ️.             -1.2354
# ️️             -1.2119
# ✘              -1.2040
# ken            -1.1986
# crime....      -1.1974
#
# For tag:  ('📷', '_camera_')
# 10 most important features:
# johnsonjohansen…1.8990
# anthonydeeying 1.8944
# #thecharlottepost1.8013
# :@kendrickomar11.7961
# #atp           1.7721
# #d45photoshoot 1.7525
# nicktrochilphotography1.7155
# :@alingtonn    1.7104
# hazelxlove27   1.6764
# jerrellturner  1.6697
# 10 least important features:
# stylists…      -2.1870
# (cover)        -1.9956
# skies.         -1.7871
# fiyah          -1.7552
# ️              -1.6354
# julieannii     -1.6195
# indie-art      -1.6061
# #kbphotography…-1.6057
# distressed.jacket-1.5815
# #shotbyjay     -1.5238
#
# For tag:  ('🇺🇸', '_United_States_')
# 10 most important features:
# #merica        2.0932
# murica         2.0706
# "america"!!!   2.0417
# sprangz        2.0377
# 'murica        2.0216
# merica         2.0212
# #madeinusa     1.9390
# #heymanhustle… 1.9385
# #twincitiesautoshow1.9349
# 🇦.             1.8824
# 10 least important features:
# ️              -3.3183
# #blur          -2.5798
# ️hrc           -2.2359
# right/duty     -2.1725
# ️#belated      -2.0836
# #traveldiaries#california-2.0328
# #aftervote     -1.9716
# glow           -1.9716
# #nopunintended -1.9680
# #mypresident   -1.9366
#
# For tag:  ('☀', '_sun_')
# 10 most important features:
# ️who…          2.5222
# ️day           2.4718
# rumpke…        2.1296
# avitamyriam    2.0414
# ️#fashionphotographer…1.9836
# ️#baltimore    1.9803
# spike…         1.9388
# bravest…       1.8897
# #kidschoiceawards1.8225
# ️set           1.8191
# 10 least important features:
# queen…         -4.9564
# it...!!!!      -4.5816
# britney:       -4.3910
# repostapp・・・warming-2.7293
# athletix       -2.5967
# sport          -2.3586
# begins!!!!!!!  -2.3586
# dome           -2.2162
# ️#monsoon      -2.1989
# dbl            -1.8741
#
# For tag:  ('💜', '_purple_heart_')
# 10 most important features:
# finwood…       1.8436
# chicora,       1.7976
# #awakening     1.7651
# dylanventura   1.7620
# #endalz        1.7506
# #purpledrink   1.7244
# #pixietour     1.7198
# perfσκt        1.6656
# #hellokittyrocks32…1.6591
# twosistersfarms1.6582
# 10 least important features:
# ️              -2.1050
# little~        -1.5505
# #cancersucks…  -1.3678
# ️…             -1.3655
# naperville,    -1.3602
# hayley         -1.3237
# #ourgirlsreign -1.2968
# #alzheimers    -1.2330
# fund:          -1.2212
# ️.             -1.1994
#
# For tag:  ('😉', '_winking_face_')
# 10 most important features:
# #sweetfest     1.7714
# soph!          1.7194
# missparadisnyc 1.7091
# #amreeca_diaries1.7010
# dreams....don't1.6914
# stone...       1.6903
# ralphie        1.6870
# stampedes      1.6813
# roglow         1.6804
# #wink          1.6684
# 10 least important features:
# ️              -1.5344
# ️…             -1.2952
# self...dreadmill-1.2041
# #sbfitco       -1.1988
# young?         -1.1918
# weather,…      -1.1907
# orifice!       -1.1229
# ha.            -1.1012
# #80sflashbacks -1.0734
# west's         -1.0431
#
# For tag:  ('💯', '_hundred_points_')
# 10 most important features:
# #realshittho   3.4404
# paiin          2.6205
# %              2.3689
# realtalk       2.0065
# misery!        1.9573
# #t3t           1.9142
# #eclecticeatery1.8411
# imo            1.8232
# #lyricb        1.8177
# cornwallis     1.7576
# 10 least important features:
# #empirestate…  -2.3876
# #shutup        -1.5481
# evolution      -1.4563
# “@iamclozz3r   -1.4354
# nicki          -1.4309
# engineering    -1.3535
# #toosoon       -1.3520
# oktoberfest    -1.3425
# everybody!     -1.2990
# whyyyyyy       -1.2763
#
# For tag:  ('😁', '_beaming_face_with_smiling_eyes_')
# 10 most important features:
# #thelemoyneowencollege…1.9741
# mattramey10    1.8246
# obsidian       1.8005
# #jimmyhayes    1.7080
# #dioneclan     1.6832
# champagnejarvi 1.6764
# party...aka...sparkle1.6726
# correctly,     1.6602
# #lyricswithmeaning1.6564
# #steve…        1.6480
# 10 least important features:
# ️              -1.2687
# :…             -1.2037
# southcliff     -1.1572
# bni            -1.1060
# sweeterville   -1.0986
# dallas/fort    -1.0888
# quincy         -1.0877
# (bwi))         -1.0841
# zeus'          -1.0820
# treatment      -1.0786
#
# For tag:  ('🎄', '_Christmas_tree_')
# 10 most important features:
# #family2nd     5.3115
# #god1st        2.8872
# swills         2.0968
# butterflies?   1.9941
# #chrismastree  1.8854
# #xmas2015      1.8721
# arrived...us   1.8559
# crusade        1.8471
# gallipolis     1.8215
# alexis!…       1.8215
# 10 least important features:
# dylanventura   -2.7457
# ️              -2.5313
# #party…        -2.5123
# owasso         -2.1519
# l.l.           -2.1475
# ️…             -2.0405
# ellms          -1.9780
# hightlight     -1.9718
# #perspective   -1.9704
# ignite         -1.9511
#
# For tag:  ('📸', '_camera_with_flash_')
# 10 most important features:
# #hippykelly    1.7875
# whoisariane    1.7813
# #sandynoseboy… 1.7779
# #centralparkmoments…1.7727
# girlfriend's…  1.7646
# taramaysphoto  1.7472
# niece/america/my1.7159
# thebsarge・・・best1.6773
# tact!          1.6676
# eastway        1.6575
# 10 least important features:
# knits          -1.8912
# photo...       -1.8106
# ️              -1.6712
# #mrherget      -1.6359
# #igworldclub   -1.4309
# fiyah          -1.4077
# ...hiking      -1.4065
# #swavenation   -1.4009
# paiin          -1.3990
# co-hosted      -1.3840
#
# For tag:  ('😜', '_winking_face_with_tongue_')
# 10 most important features:
# #bahamas,      2.2302
# brat!          1.8439
# hope...you're  1.8302
# logan_leiby    1.7800
# 18!!           1.7258
# #weallwonstuffedanimals…1.6593
# (many)         1.6534
# lectures       1.6499
# ...be          1.6422
# #cheesybuttrue…1.6375
# 10 least important features:
# ️              -1.4377
# {beach}        -1.1687
# 1/2            -1.1236
# ️…             -1.0791
# 1.5            -1.0733
# :…             -1.0284
# sorted!        -1.0118
# 206            -0.9976
# unplaned       -0.9929
# prize          -0.9919
